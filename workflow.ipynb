# %%
## Basic Parameters
base_treatments = ["ATP", "MSU", "Nigericin"]
modifier = "MCC950"
short_name_dict = {"nig": "Nigericin"}
time_limits = {"ALL": 21}
exclusion_list = [("speck", ("MSU", 1), ("MSU", 2), ("MCC950*", 1))]

# %%
#Build the analysis module
from modules.workflow_functions import prepare_analysis_class
TAS = prepare_analysis_class(base_treatments=base_treatments, modifier=modifier, short_name_dict=short_name_dict, time_limits=time_limits, exclusion_list=exclusion_list)

# %%
#Generate the plots and reports
from modules.workflow_functions import generate_plots
from modules.workflow_functions import generate_reports
generate_plots(TAS, file_extension=".png")
generate_reports(TAS)
# Out:
# Index(['Analyte', 'Treatment', 'Time (hrs)', 'Experimental_Replicate',
#        'Signal', 'Measurement', 'Normalized_Measurement', 'Normalized_Change',
#        'Change_Rate', 'Absolute_Change', 'Change_Rate_Diff',
#        'Change_Rate_Lagging', 'Change_Rate_Diff_Lagging', 'Delta',
#        'Normalized_Delta', 'Delta_Smooth', 'Normalized_Delta_Smooth',
#        'Acceleration', 'Normalized_Acceleration', 'Acceleration_Smooth',
#        'Normalized_Acceleration_Smooth'],
#       dtype='object')
# Data for Treatment ATP and Analyte IL18 is normally distributed
# 0.7733590602874756
# Data for Treatment MSU and Analyte IL18 is not normally distributed
# 0.02296825684607029
# Data for Treatment Nigericin and Analyte IL18 is not normally distributed
# 0.002254814375191927
# Data for Treatment ATP and Analyte IL1b is normally distributed
# 0.5274486541748047
# Data for Treatment MSU and Analyte IL1b is normally distributed
# 0.4113544225692749
# Data for Treatment Nigericin and Analyte IL1b is normally distributed
# 0.06626181304454803
# Index(['Analyte', 'Treatment', 'Time (hrs)', 'Experimental_Replicate',
#        'Measurement', 'Normalized_Measurement', 'Normalized_Change',
#        'Change_Rate', 'Absolute_Change', 'Change_Rate_Diff',
#        'Change_Rate_Lagging', 'Change_Rate_Diff_Lagging', 'Delta',
#        'Normalized_Delta', 'Delta_Smooth', 'Normalized_Delta_Smooth',
#        'Acceleration', 'Normalized_Acceleration', 'Acceleration_Smooth',
#        'Normalized_Acceleration_Smooth'],
#       dtype='object')
# Data for Treatment ATP and Analyte NA is normally distributed
# 0.15282513201236725
# Data for Treatment MCC950_ATP and Analyte NA is not normally distributed
# 0.012546033598482609
# Data for Treatment MCC950_MSU and Analyte NA is normally distributed
# 0.6263437271118164
# Data for Treatment MCC950_Nigericin and Analyte NA is normally distributed
# 0.1640642285346985
# Data for Treatment MSU and Analyte NA is normally distributed
# 0.5995985269546509
# Data for Treatment Nigericin and Analyte NA is normally distributed
# 0.07932925969362259
# ATP
# 30    1.275229
# 31    2.155172
# 32    1.759259
# 33    2.634921
# 34    3.263636
# Name: Normalized_Measurement, dtype: float64
# 498    1.514881
# 499    2.130631
# 500    1.720721
# 501    1.408907
# 502    1.834061
# Name: Normalized_Measurement, dtype: float64
# 5    1.284404
# 6    1.534483
# 7    1.481481
# 8    2.031746
# 9    1.972727
# Name: Change_Rate, dtype: float64
# 378    1.112500
# 379    1.122642
# 380    1.017442
# 381    1.066667
# 382    1.058824
# Name: Change_Rate, dtype: float64
# MSU
# 1213    7.246835
# 1214    5.235088
# 1215    4.622478
# 1216    5.904762
# 1217    4.141509
# Name: Normalized_Measurement, dtype: float64
# 786    2.831111
# 787    1.724026
# 788    3.404255
# 789    3.968254
# 790    2.606299
# Name: Normalized_Measurement, dtype: float64
# 1143    1.655941
# 1144    1.539823
# 1145    1.548009
# 1146    1.577519
# 1147    1.287938
# Name: Change_Rate, dtype: float64
# 636    0.986188
# 637    1.052023
# 638    1.118012
# 639    1.047120
# 640    1.167286
# Name: Change_Rate, dtype: float64
# Nigericin
# 1460     53.731707
# 1461     56.595238
# 1462     40.098361
# 1463    102.829268
# 1464     72.509804
# Name: Normalized_Measurement, dtype: float64
# 888    3.810811
# 889    3.729630
# 890    4.575610
# 891    4.413043
# 892    4.769231
# Name: Normalized_Measurement, dtype: float64
# 1445    25.560976
# 1446    22.761905
# 1447    26.655738
# 1448     6.975610
# 1449     4.843137
# Name: Change_Rate, dtype: float64
# 840    1.610039
# 841    1.185185
# 842    1.560976
# 843    1.864130
# 844    1.752747
# Name: Change_Rate, dtype: float64
# ATP is significant between 1.0 and 24.0.
# MSU is significant between 1.0 and 24.0.
# Nigericin is significant between 1.0 and 24.0.
# ATP is significant between 1.0 and 24.0.
# MSU is significant between 1.0 and 24.0.
# Nigericin is significant between 1.0 and 24.0.
# ATP is significant between 2.0 and 3.0.
# MCC950_ATP is significant between 5.0 and 21.0.
# MCC950_MSU is significant between 9.0 and 21.0.
# MCC950_Nigericin is significant between 0.5 and 21.0.
# MSU is significant between 1.0 and 21.0.
# Nigericin is significant between 0.5 and 21.0.
